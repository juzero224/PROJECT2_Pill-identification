# %%
# 런타임 -> gpu 설정

# %%
# from google.colab import drive  # 알약파일 가져오기위해
# drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/ultralytics/yolov5  # yolov5 코드 clone
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 12000, done.
# remote: Counting objects: 100% (47/47), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 12000 (delta 30), reused 39 (delta 25), pack-reused 11953
# Receiving objects: 100% (12000/12000), 12.50 MiB | 12.86 MiB/s, done.
# Resolving deltas: 100% (8254/8254), done.

# %%
# %cd yolov5
# Out:
# /content/yolov5

# %%
# %pip install -qr requirements.txt
# Out:
#      |████████████████████████████████| 1.6 MB 39.1 MB/s

# %%
# !unzip /content/drive/MyDrive/custom_dataset.zip # 알약 데이터 압축 해제
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: custom_dataset/train/labels/after2_17159-------------_crop_173_png.rf.ddbdb5b823c305ae252b57ec3227d275.txt
#   inflating: __MACOSX/custom_dataset/train/labels/._after2_17159-------------_crop_173_png.rf.ddbdb5b823c305ae252b57ec3227d275.txt
#   inflating: custom_dataset/train/labels/22074------------------------_crop_075_png.rf.af3899f3f71b8071e00dd94e3813e6c0.txt
#   inflating: __MACOSX/custom_dataset/train/labels/._22074------------------------_crop_075_png.rf.af3899f3f71b8071e00dd94e3813e6c0.txt
#   inflating: custom_dataset/train/labels/after1_17458-------------------------_crop_020_png.rf.f3246ea9b36bac5e084d23c332a68219.txt
#   inflating: __MACOSX/custom_dataset/train/labels/._after1_17458-------------------------_crop_020_png.rf.f3246ea9b36bac5e084d23c332a68219.txt
#   inflating: custom_dataset/train/labels/after1_3324--------------_black_024_png.rf.26a3020dc156061d66dc91a773396051.txt
# ...

# %%
# /yolov5/data/(여기에 custom_dataset.yaml 파일을 생성하여 클래스 경로, 수, 이름을 지정해줍니다.)

# %%
# !python train.py --data "/content/yolov5/data/custom_dataset.yaml" --epochs 100 # epoch 100으로 설정 후 학습
# Out:
# train: weights=yolov5s.pt, cfg=, data=/content/yolov5/data/custom_dataset.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.2-10-g5c854fa Python-3.7.13 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# 학습이 완료된 best.pt를 weight로 설정, --source에 이미지를 인식할 사진의 경로를 설정해줍니다. (저는 코랩에 사진을 업로드하여 사용했습니다.)
# 학습된 best.pt파일을 따로 첨부하였으니 파일을 넣은뒤 경로지정만 해주시면 됩니다.(/content/yolov5/runs/train/exp/weights/best.pt 원래 경로)

# %%
# !python /content/yolov5/detect.py --weights /content/best.pt --img 320 --conf 0.5 --source /content/12063_한미오메가.png
# Out:
# detect: weights=['/content/best.pt'], source=/content/12063_한미오메가.png, data=data/coco128.yaml, imgsz=[320, 320], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.2-47-geab35f6 Python-3.7.13 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7037095 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/12063_한미오메가.png: 320x320 1 12063, 10.2ms
# Speed: 0.4ms pre-process, 10.2ms inference, 40.8ms NMS per image at shape (1, 3, 320, 320)
# Results saved to runs/detect/exp

# %%
# 인식이 완료된 이미지 파일이 경로에 저장됩니다. 알약을 확인하는 함수입니다.

# %%
import cv2
from google.colab.patches import cv2_imshow

img = cv2.imread('/content/yolov5/runs/detect/exp/12063_한미오메가.png')
cv2_imshow(img)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# !python /content/yolov5/detect.py --weights /content/best.pt --img 320 --conf 0.5 --source /content/2070_탁센.jpg
# Out:
# detect: weights=['/content/best.pt'], source=/content/2070_탁센.jpg, data=data/coco128.yaml, imgsz=[320, 320], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.2-47-geab35f6 Python-3.7.13 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7037095 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/2070_탁센.jpg: 320x320 1 2070, 7.6ms
# Speed: 0.4ms pre-process, 7.6ms inference, 1.1ms NMS per image at shape (1, 3, 320, 320)
# Results saved to runs/detect/exp2

# %%
import cv2
from google.colab.patches import cv2_imshow

img = cv2.imread('/content/yolov5/runs/detect/exp2/2070_탁센.jpg')
cv2_imshow(img)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# !python /content/yolov5/detect.py --weights /content/best.pt --img 320 --conf 0.5 --source /content/22605_타이레놀.png
# Out:
# detect: weights=['/content/best.pt'], source=/content/22605_타이레놀.png, data=data/coco128.yaml, imgsz=[320, 320], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.2-47-geab35f6 Python-3.7.13 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7037095 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/22605_타이레놀.png: 320x320 1 3324, 7.8ms
# Speed: 0.4ms pre-process, 7.8ms inference, 1.2ms NMS per image at shape (1, 3, 320, 320)
# Results saved to runs/detect/exp3

# %%
import cv2
from google.colab.patches import cv2_imshow

img = cv2.imread('/content/yolov5/runs/detect/exp3/22605_타이레놀.png') # 예측 실패
cv2_imshow(img)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# !python /content/yolov5/detect.py --weights /content/best.pt --img 320 --conf 0.5 --source /content/8998.이소티논.jpeg
# Out:
# detect: weights=['/content/best.pt'], source=/content/8998.이소티논.jpeg, data=data/coco128.yaml, imgsz=[320, 320], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.2-47-geab35f6 Python-3.7.13 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7037095 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/8998.이소티논.jpeg: 320x320 1 8998, 7.8ms
# Speed: 0.4ms pre-process, 7.8ms inference, 1.2ms NMS per image at shape (1, 3, 320, 320)
# Results saved to runs/detect/exp4

# %%
import cv2
from google.colab.patches import cv2_imshow

img = cv2.imread('/content/yolov5/runs/detect/exp4/8998.이소티논.jpeg')
cv2_imshow(img)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# !python /content/yolov5/detect.py --weights /content/best.pt --img 320 --conf 0.5 --source /content/겹침1.jpg
# Out:
# detect: weights=['/content/best.pt'], source=/content/겹침1.jpg, data=data/coco128.yaml, imgsz=[320, 320], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.2-47-geab35f6 Python-3.7.13 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7037095 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/겹침1.jpg: 320x320 1 12063, 7.8ms
# Speed: 0.4ms pre-process, 7.8ms inference, 1.3ms NMS per image at shape (1, 3, 320, 320)
# Results saved to runs/detect/exp5

# %%
import cv2
from google.colab.patches import cv2_imshow

img = cv2.imread('/content/yolov5/runs/detect/exp5/겹침1.jpg')
cv2_imshow(img)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# !python /content/yolov5/detect.py --weights /content/best.pt --img 320 --conf 0.5 --source /content/겹침2.jpg
# Out:
# detect: weights=['/content/best.pt'], source=/content/겹침2.jpg, data=data/coco128.yaml, imgsz=[320, 320], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.2-47-geab35f6 Python-3.7.13 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7037095 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/겹침2.jpg: 320x320 1 12063, 1 2070, 7.8ms
# Speed: 0.4ms pre-process, 7.8ms inference, 1.1ms NMS per image at shape (1, 3, 320, 320)
# Results saved to runs/detect/exp6

# %%
import cv2
from google.colab.patches import cv2_imshow

img = cv2.imread('/content/yolov5/runs/detect/exp6/겹침2.jpg')
cv2_imshow(img)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
